# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive/Jersey_Detection/image_segmentation")
import os
os.chdir("/content/drive/MyDrive/Jersey_Detection/image_segmentation")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-kkm5kghp
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-kkm5kghp
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment_anything: filename=segment_anything-1.0-py3-none-any.whl size=36592 sha256=fc4548008447267637680c6c361d8d3759fd8f669d2fae43d0e9c5c0a2534c0f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0qf3nso4/wheels/29/82/ff/04e2be9805a1cb48bec0b85b5a6da6b63f647645750a0e42d4
# Successfully built segment_anything
# ...

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# --2026-03-10 21:06:20--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 54.230.79.88, 54.230.79.53, 54.230.79.122, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|54.230.79.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth.2’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G  80.6MB/s    in 30s
#
# 2026-03-10 21:06:51 (80.3 MB/s) - ‘sam_vit_h_4b8939.pth.2’ saved [2564550879/2564550879]

# %%
from pathlib import Path
from segment import segmentation

# %%
image_folder = Path("/content/drive/MyDrive/Jersey_Detection/images")
image_files = [str(f) for f in image_folder.iterdir() if f.is_file()]

# %%
for img_path in image_files:
    print(f"cur_image: {img_path}")
    cur_image = segmentation(img_path)
    cur_image.segment_image()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
